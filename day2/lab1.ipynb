# %%
# Load the data.table library
library(data.table)

# Read the CitiBike trip data for September 2018
df <- fread("2018-citibike-tripdata/9_September/201809-citibike-tripdata_1.csv")

df=data.table(df)
# Show first few rows
head(df)
# Out:
#   tripduration starttime           stoptime            start station id
# 1 1635         2018-09-01 00:00:05 2018-09-01 00:27:20  252
# 2  132         2018-09-01 00:00:11 2018-09-01 00:02:23  314
# 3 3337         2018-09-01 00:00:20 2018-09-01 00:55:58 3142
# 4  436         2018-09-01 00:00:21 2018-09-01 00:07:38  308
# 5 8457         2018-09-01 00:00:27 2018-09-01 02:21:25  345
# 6 3326         2018-09-01 00:00:29 2018-09-01 00:55:56 3142
#   start station name              start station latitude
# 1 MacDougal St & Washington Sq    40.73226
# 2 Cadman Plaza West & Montague St 40.69383
# 3 1 Ave & E 62 St                 40.76123
# 4 St James Pl & Oliver St         40.71308
# 5 W 13 St & 6 Ave                 40.73649
# 6 1 Ave & E 62 St                 40.76123
#   start station longitude end station id end station name
# 1 -73.99852                366           Clinton Ave & Myrtle Ave
# 2 -73.99054               3242           Schermerhorn St & Court St
# 3 -73.96094               3384           Smith St & 3 St
# 4 -73.99851               3690           Park Pl & Church St
# 5 -73.99704                380           W 4 St & 7 Ave S
# 6 -73.96094               3384           Smith St & 3 St
#   end station latitude end station longitude bikeid usertype   birth year
# 1 40.69326             -73.96890             25577  Subscriber 1980
# 2 40.69103             -73.99183             34377  Subscriber 1969
# 3 40.67872             -73.99599             30496  Subscriber 1975
# 4 40.71334             -74.00936             28866  Subscriber 1984
# 5 40.73401             -74.00294             20943  Customer   1994
# 6 40.67872             -73.99599             21693  Subscriber 1977
#   gender
# 1 1
# 2 0
# 3 1
# 4 2
# 5 1
# 6 2

# %%
# View the first 10 lines
cat("=== FIRST 10 LINES ===\n")
head(df, 10)

cat("\n\n=== FIRST 20 LINES ===\n")
# View the first 20 lines
head(df, 20)
# Out:
# === FIRST 10 LINES ===
#    tripduration starttime           stoptime            start station id
# 1  1635         2018-09-01 00:00:05 2018-09-01 00:27:20  252
# 2   132         2018-09-01 00:00:11 2018-09-01 00:02:23  314
# 3  3337         2018-09-01 00:00:20 2018-09-01 00:55:58 3142
# 4   436         2018-09-01 00:00:21 2018-09-01 00:07:38  308
# 5  8457         2018-09-01 00:00:27 2018-09-01 02:21:25  345
# 6  3326         2018-09-01 00:00:29 2018-09-01 00:55:56 3142
# 7   233         2018-09-01 00:00:27 2018-09-01 00:04:20 3526
# 8   285         2018-09-01 00:00:31 2018-09-01 00:05:17  358
# 9  1127         2018-09-01 00:00:30 2018-09-01 00:19:18  285
# 10  423         2018-09-01 00:00:42 2018-09-01 00:07:45  319
#    start station name              start station latitude
# 1  MacDougal St & Washington Sq    40.73226
# 2  Cadman Plaza West & Montague St 40.69383
# 3  1 Ave & E 62 St                 40.76123
# 4  St James Pl & Oliver St         40.71308
# 5  W 13 St & 6 Ave                 40.73649
# 6  1 Ave & E 62 St                 40.76123
# 7  31 St & 23 Ave                  40.77479
# 8  Christopher St & Greenwich St   40.73292
# 9  Broadway & E 14 St              40.73455
# 10 Fulton St & Broadway            40.71107
#    start station longitude end station id end station name
# 1  -73.99852                366           Clinton Ave & Myrtle Ave
# 2  -73.99054               3242           Schermerhorn St & Court St
# 3  -73.96094               3384           Smith St & 3 St
# 4  -73.99851               3690           Park Pl & Church St
# 5  -73.99704                380           W 4 St & 7 Ave S
# 6  -73.96094               3384           Smith St & 3 St
# 7  -73.91256               3532           Ditmars Blvd & 19 St
# 8  -74.00711                405           Washington St & Gansevoort St
# 9  -73.99074                405           Washington St & Gansevoort St
# 10 -74.00945                426           West St & Chambers St
#    end station latitude end station longitude bikeid usertype   birth year
# 1  40.69326             -73.96890             25577  Subscriber 1980
# 2  40.69103             -73.99183             34377  Subscriber 1969
# 3  40.67872             -73.99599             30496  Subscriber 1975
# 4  40.71334             -74.00936             28866  Subscriber 1984
# 5  40.73401             -74.00294             20943  Customer   1994
# 6  40.67872             -73.99599             21693  Subscriber 1977
# 7  40.78145             -73.91833             29789  Subscriber 1989
# 8  40.73932             -74.00812             32861  Subscriber 1991
# 9  40.73932             -74.00812             25039  Subscriber 1982
# 10 40.71755             -74.01322             20508  Subscriber 1974
#    gender
# 1  1
# 2  0
# 3  1
# 4  2
# 5  1
# 6  2
# 7  1
# 8  1
# 9  1
# 10 2
# === FIRST 20 LINES ===
#    tripduration starttime           stoptime            start station id
# 1  1635         2018-09-01 00:00:05 2018-09-01 00:27:20  252
# 2   132         2018-09-01 00:00:11 2018-09-01 00:02:23  314
# 3  3337         2018-09-01 00:00:20 2018-09-01 00:55:58 3142
# 4   436         2018-09-01 00:00:21 2018-09-01 00:07:38  308
# 5  8457         2018-09-01 00:00:27 2018-09-01 02:21:25  345
# 6  3326         2018-09-01 00:00:29 2018-09-01 00:55:56 3142
# 7   233         2018-09-01 00:00:27 2018-09-01 00:04:20 3526
# 8   285         2018-09-01 00:00:31 2018-09-01 00:05:17  358
# 9  1127         2018-09-01 00:00:30 2018-09-01 00:19:18  285
# 10  423         2018-09-01 00:00:42 2018-09-01 00:07:45  319
# 11  327         2018-09-01 00:00:45 2018-09-01 00:06:12 3509
# 12  541         2018-09-01 00:00:45 2018-09-01 00:09:47 3077
# 13  535         2018-09-01 00:01:12 2018-09-01 00:10:07  500
# 14  147         2018-09-01 00:01:16 2018-09-01 00:03:43 3134
# 15  454         2018-09-01 00:01:19 2018-09-01 00:08:53  479
# 16  893         2018-09-01 00:01:20 2018-09-01 00:16:13 3558
# 17 1138         2018-09-01 00:01:29 2018-09-01 00:20:27 3107
# 18  401         2018-09-01 00:01:32 2018-09-01 00:08:14  350
# 19  353         2018-09-01 00:01:46 2018-09-01 00:07:40 3384
# 20  252         2018-09-01 00:02:03 2018-09-01 00:06:15  350
#    start station name              start station latitude
# 1  MacDougal St & Washington Sq    40.73226
# 2  Cadman Plaza West & Montague St 40.69383
# 3  1 Ave & E 62 St                 40.76123
# 4  St James Pl & Oliver St         40.71308
# 5  W 13 St & 6 Ave                 40.73649
# 6  1 Ave & E 62 St                 40.76123
# 7  31 St & 23 Ave                  40.77479
# 8  Christopher St & Greenwich St   40.73292
# 9  Broadway & E 14 St              40.73455
# 10 Fulton St & Broadway            40.71107
# 11 Lenox Ave & W 115 St            40.80119
# 12 Stagg St & Union Ave            40.70877
# 13 Broadway & W 51 St              40.76229
# 14 3 Ave & E 62 St                 40.76313
# 15 9 Ave & W 45 St                 40.76019
# 16 Bergen St & Vanderbilt Ave      40.67944
# 17 Bedford Ave & Nassau Ave        40.72312
# 18 Clinton St & Grand St           40.71560
# 19 Smith St & 3 St                 40.67872
# 20 Clinton St & Grand St           40.71560
#    start station longitude end station id end station name
# 1  -73.99852                366           Clinton Ave & Myrtle Ave
# 2  -73.99054               3242           Schermerhorn St & Court St
# 3  -73.96094               3384           Smith St & 3 St
# 4  -73.99851               3690           Park Pl & Church St
# 5  -73.99704                380           W 4 St & 7 Ave S
# 6  -73.96094               3384           Smith St & 3 St
# 7  -73.91256               3532           Ditmars Blvd & 19 St
# 8  -74.00711                405           Washington St & Gansevoort St
# 9  -73.99074                405           Washington St & Gansevoort St
# 10 -74.00945                426           West St & Chambers St
# 11 -73.95007               3518           Lenox Ave & W 126 St
# 12 -73.95095               3059           Pulaski St & Marcus Garvey Blvd
# 13 -73.98336                493           W 45 St & 6 Ave
# 14 -73.96527               3376           E 65 St & 2 Ave
# 15 -73.99126                458           11 Ave & W 27 St
# 16 -73.96804               3396           Clinton St & 4 Place
# 17 -73.95212                372           Franklin Ave & Myrtle Ave
# 18 -73.98703                473           Rivington St & Chrystie St
# 19 -73.99599               3389           Carroll St & Columbia St
# 20 -73.98703                308           St James Pl & Oliver St
#    end station latitude end station longitude bikeid usertype   birth year
# 1  40.69326             -73.96890             25577  Subscriber 1980
# 2  40.69103             -73.99183             34377  Subscriber 1969
# 3  40.67872             -73.99599             30496  Subscriber 1975
# 4  40.71334             -74.00936             28866  Subscriber 1984
# 5  40.73401             -74.00294             20943  Customer   1994
# 6  40.67872             -73.99599             21693  Subscriber 1977
# 7  40.78145             -73.91833             29789  Subscriber 1989
# 8  40.73932             -74.00812             32861  Subscriber 1991
# 9  40.73932             -74.00812             25039  Subscriber 1982
# 10 40.71755             -74.01322             20508  Subscriber 1974
# 11 40.80844             -73.94521             31497  Subscriber 1993
# 12 40.69340             -73.93988             21632  Subscriber 1990
# 13 40.75680             -73.98291             21698  Customer   1971
# 14 40.76472             -73.96222             32191  Subscriber 1995
# 15 40.75140             -74.00523             16773  Subscriber 1983
# 16 40.67836             -74.00015             17360  Customer   1987
# 17 40.69455             -73.95801             18964  Customer   1985
# 18 40.72110             -73.99193             29786  Subscriber 1984
# 19 40.68305             -74.00349             25552  Subscriber 1985
# 20 40.71308             -73.99851             32175  Subscriber 1982
#    gender
# 1  1
# 2  0
# 3  1
# 4  2
# 5  1
# 6  2
# 7  1
# 8  1
# 9  1
# 10 2
# 11 1
# 12 1
# 13 1
# 14 1
# 15 1
# 16 1
# 17 1
# 18 1
# 19 1
# 20 1

# %%
cat("=== TRIP DURATION STATISTICS ===\n\n")

# Calculate all statistics
trip_mean <- mean(df$tripduration, na.rm = TRUE)
trip_median <- median(df$tripduration, na.rm = TRUE)
trip_sd <- sd(df$tripduration, na.rm = TRUE)
trip_iqr <- IQR(df$tripduration, na.rm = TRUE)

# Display each statistic separately
cat("Mean:", round(trip_mean, 2), "seconds\n")
cat("Median:", round(trip_median, 2), "seconds\n")
cat("Standard Deviation:", round(trip_sd, 2), "seconds\n")
cat("IQR:", round(trip_iqr, 2), "seconds\n")

cat("\n--- Converted to minutes ---\n")
cat("Mean:", round(trip_mean/60, 2), "minutes\n")
cat("Median:", round(trip_median/60, 2), "minutes\n")
cat("Standard Deviation:", round(trip_sd/60, 2), "minutes\n")
cat("IQR:", round(trip_iqr/60, 2), "minutes\n")
# Out:
# === TRIP DURATION STATISTICS ===
#
# Mean: 1012.17 seconds
# Median: 647 seconds
# Standard Deviation: 9967.31 seconds
# IQR: 769 seconds
#
# --- Converted to minutes ---
# Mean: 16.87 minutes
# Median: 10.78 minutes
# Standard Deviation: 166.12 minutes
# IQR: 12.82 minutes

# %%
# TASK 5a: Find the 67th percentile and 4th decile of tripduration
cat("=== PERCENTILES AND DECILES ===\n\n")

# Calculate 67th percentile
percentile_67 <- quantile(df$tripduration, probs = 0.67, na.rm = TRUE)

# Calculate 4th decile (40th percentile)
decile_4 <- quantile(df$tripduration, probs = 0.4, na.rm = TRUE)

# Display results
cat("67th percentile:", round(percentile_67, 2), "seconds (", round(percentile_67/60, 2), "minutes)\n")
cat("4th decile (40th percentile):", round(decile_4, 2), "seconds (", round(decile_4/60, 2), "minutes)\n")

# Definitions
cat("\n=== DEFINITIONS ===\n")
cat("• 67th PERCENTILE: The value below which 67% of the trip durations fall.\n")
cat("  This means 67% of trips are shorter than", round(percentile_67/60, 2), "minutes.\n\n")
cat("• 4th DECILE (40th percentile): The value below which 40% of the trip durations fall.\n")
cat("  This means 40% of trips are shorter than", round(decile_4/60, 2), "minutes.\n")
cat("  Deciles divide data into 10 equal parts (1st decile = 10th percentile, 2nd = 20th, etc.)\n")
# Out:
# === PERCENTILES AND DECILES ===
#
# 67th percentile: 942 seconds ( 15.7 minutes)
# 4th decile (40th percentile): 526 seconds ( 8.77 minutes)
#
# === DEFINITIONS ===
# • 67th PERCENTILE: The value below which 67% of the trip durations fall.
#   This means 67% of trips are shorter than 15.7 minutes.
#
# • 4th DECILE (40th percentile): The value below which 40% of the trip durations fall.
#   This means 40% of trips are shorter than 8.77 minutes.
#   Deciles divide data into 10 equal parts (1st decile = 10th percentile, 2nd = 20th, etc.)

# %%
# TASK 5b: Find total number of trips and breakdown by gender
cat("=== TRIP COUNTS ===\n\n")

# Total number of trips (rows in the dataset)
total_trips <- nrow(df)
cat("Total number of trips:", total_trips, "\n\n")

cat("Gender distribution:\n")

# Count trips by gender (1 = men, 2 = women)
gender_counts <- table(df$gender, useNA = "ifany")
print(gender_counts)

# More detailed breakdown
men_trips <- sum(df$gender == 1, na.rm = TRUE)
women_trips <- sum(df$gender == 2, na.rm = TRUE)
unknown_gender <- sum(is.na(df$gender) | df$gender == 0)

cat("\nDetailed breakdown:\n")
cat("Men (gender = 1):", men_trips, "trips\n")
cat("Women (gender = 2):", women_trips, "trips\n")
cat("Unknown/Other gender:", unknown_gender, "trips\n")

# Percentages
cat("\nPercentages:\n")
cat("Men:", round(men_trips/total_trips * 100, 1), "%\n")
cat("Women:", round(women_trips/total_trips * 100, 1), "%\n")
cat("Unknown/Other:", round(unknown_gender/total_trips * 100, 1), "%\n")
# Out:
# === TRIP COUNTS ===
#
# Total number of trips: 1000000
#
# Gender distribution:
#
#      0      1      2
# 103169 651245 245586
#
# Detailed breakdown:
# Men (gender = 1): 651245 trips
# Women (gender = 2): 245586 trips
# Unknown/Other gender: 103169 trips
#
# Percentages:
# Men: 65.1 %
# Women: 24.6 %
# Unknown/Other: 10.3 %

# %%
# TASK 6: Make a histogram for birth year column
cat("=== HISTOGRAM OF BIRTH YEAR ===\n\n")

if(!is.null(df$`birth year`)) {
  # Clean the data
  birth_years <- df$`birth year`
  birth_years_clean <- birth_years[!is.na(birth_years) & birth_years > 1900 & birth_years < 2020] 
}

cat("Valid birth years:", length(birth_years_clean), "out of", length(birth_years), "\n")
cat("Birth year range:", min(birth_years_clean), "to", max(birth_years_clean), "\n\n")

# Create histogram
hist(birth_years_clean, 
      main = "Distribution of Birth Years - CitiBike Users",
      xlab = "Birth Year",
      ylab = "Frequency (Number of Users)",
      col = "lightblue",
      border = "darkblue",
      breaks = 20)

# Add some statistics to the plot
abline(v = mean(birth_years_clean), col = "red", lwd = 2, lty = 2)
abline(v = median(birth_years_clean), col = "green", lwd = 2, lty = 2)
legend("topleft", 
        legend = c("Mean", "Median"), 
        col = c("red", "green"), 
        lty = 2, lwd = 2)


cat("\n=== WHAT IS A HISTOGRAM? ===\n")
cat("A histogram is a graphical representation that shows the distribution of a dataset.\n")
cat("It divides the data into bins (intervals) and shows how many data points fall into each bin.\n")
cat("Key features:\n")
cat("• X-axis: Shows the range of values (birth years)\n")
cat("• Y-axis: Shows frequency (how many people born in each year range)\n")
cat("• Bars: Height represents the number of observations in each bin\n")
cat("• Shape: Reveals patterns like normal distribution, skewness, or multiple peaks\n")
# Out:
# === HISTOGRAM OF BIRTH YEAR ===
# Error: objet 'birth_years_clean' introuvable
# Traceback:
#
# 1. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "objet 'birth_years_clean' introuvable", base::quote(eval(expr,
#  .     envir)))

# %%
# TASK 7: Make a boxplot for birth year
cat("=== BOXPLOT OF BIRTH YEAR ===\n\n")


if(!is.null(df$`birth year`)) {
  # Create boxplot
  boxplot(birth_years_clean,
          main = "Boxplot of Birth Years - CitiBike Users",
          ylab = "Birth Year",
          col = "lightcoral",
          border = "darkred",
          horizontal = FALSE)
  
  # Add grid for easier reading
  grid(nx = NA, ny = NULL, col = "gray", lty = "dotted")
  
  # Calculate and display key statistics
  q1 <- quantile(birth_years_clean, 0.25)
  median_year <- median(birth_years_clean)
  q3 <- quantile(birth_years_clean, 0.75)
  iqr <- q3 - q1
  
  cat("Key statistics from the boxplot:\n")
  cat("Q1 (25th percentile):", q1, "\n")
  cat("Median (50th percentile):", median_year, "\n")
  cat("Q3 (75th percentile):", q3, "\n")
  cat("IQR (Interquartile Range):", iqr, "\n")
  
} else {
  cat("Birth year column not found. Available columns:\n")
  print(names(df))
}

cat("\n=== WHAT IS A BOXPLOT? ===\n")
cat("A boxplot (box-and-whisker plot) is a standardized way to display data distribution.\n")
cat("It shows five key statistics:\n\n")
cat("• BOTTOM WHISKER: Minimum value (or 1.5×IQR below Q1)\n")
cat("• BOTTOM OF BOX (Q1): 25th percentile - 25% of data is below this line\n")
cat("• MIDDLE LINE (MEDIAN): 50th percentile - middle value that splits data in half\n")
cat("• TOP OF BOX (Q3): 75th percentile - 75% of data is below this line\n")
cat("• TOP WHISKER: Maximum value (or 1.5×IQR above Q3)\n")
cat("• DOTS (if any): Outliers - values that fall outside the whiskers\n\n")
cat("The BOX contains the middle 50% of the data (from Q1 to Q3).\n")
cat("Boxplots are excellent for:\n")
cat("• Comparing distributions between groups\n")
cat("• Identifying outliers\n")
cat("• Understanding data spread and skewness\n")
# Out:
# === BOXPLOT OF BIRTH YEAR ===
# Key statistics from the boxplot:
# Q1 (25th percentile): 1969
# Median (50th percentile): 1982
# Q3 (75th percentile): 1989
# IQR (Interquartile Range): 20
#
# === WHAT IS A BOXPLOT? ===
# A boxplot (box-and-whisker plot) is a standardized way to display data distribution.
# It shows five key statistics:
#
# • BOTTOM WHISKER: Minimum value (or 1.5×IQR below Q1)
# • BOTTOM OF BOX (Q1): 25th percentile - 25% of data is below this line
# • MIDDLE LINE (MEDIAN): 50th percentile - middle value that splits data in half
# • TOP OF BOX (Q3): 75th percentile - 75% of data is below this line
# • TOP WHISKER: Maximum value (or 1.5×IQR above Q3)
# • DOTS (if any): Outliers - values that fall outside the whiskers
#
# The BOX contains the middle 50% of the data (from Q1 to Q3).
# Boxplots are excellent for:
# • Comparing distributions between groups
# • Identifying outliers
# • Understanding data spread and skewness
# Plot with title “Boxplot of Birth Years - CitiBike Users”
